# %% [markdown]
# ## Magic Method

# %%
# %pylab inline #簡化版魔術指令
# Out:
# UsageError: unrecognized arguments: #簡化版魔術指令

# %% [markdown]
# - pylab：python的實驗室
# - inline：畫圖時，直接於瀏覽器顯示

# %% [markdown]
# Python會數學

# %%
pi
# Out:
# 3.141592653589793

# %%
sin(pi/2)
# Out:
# 1.0

# %%
cos(pi)
# Out:
# -1.0

# %%
plot([0,1,2,3,4])
# list中為y值，x會自動補上0, 1, 2,...

# %%
#numpy亂數指令
randn(10) #從常態分佈（平均值為0，標準差為1）中找出的亂數
# Out:
# array([-0.34781453,  0.66509422, -3.05840771,  0.13878172,  0.82760157,
#         0.35053549,  0.95661882,  0.76511042,  0.08030247, -1.19390008])

# %%
plot(randn(100))

# %%
plot([-2, 1, 2.7, 3.3], [3, -5, 6, 0])
#plot(x軸座標, y軸座標)

# %% [markdown]
# ---

# %% [markdown]
# ### 隨機函式

# %%
import numpy as np

# %%
np.random.rand(2, 3)
# Out:
# array([[0.6852195 , 0.20445225, 0.87811744],
#        [0.02738759, 0.67046751, 0.4173048 ]])

# %%
np.random.rand(2, 3, 4)
# Out:
# array([[[0.6313557 , 0.89408194, 0.15488604, 0.06782768],
#         [0.68288275, 0.60946259, 0.38781632, 0.73861597],
#         [0.32914389, 0.28997312, 0.18071177, 0.20949215]],
#
#        [[0.4477313 , 0.78821262, 0.11426555, 0.81428998],
#         [0.66737157, 0.99489922, 0.56893378, 0.31914287],
#         [0.75160793, 0.35091326, 0.52836748, 0.29405289]]])

# %%
np.random.randn()
# Out:
# float

# %%
np.random.randn(5, 2)
# Out:
# array([[ 0.09035118, -0.18659747],
#        [ 0.74325857, -0.41917807],
#        [ 0.00496046, -0.83355727],
#        [-0.37935889, -0.54362249],
#        [ 1.08361763,  0.12180609]])

# %%
np.random.randn(2, 3, 4)
# Out:
# array([[[ 0.65364026, -0.08915495,  0.90087165,  1.40248666],
#         [ 0.21768255, -0.08359946, -1.83797562, -0.20606241],
#         [ 0.04215544, -1.40456061,  1.97969053, -0.59401942]],
#
#        [[ 0.98821644,  0.18310407,  0.92399299,  0.53317198],
#         [-0.58513304, -0.56053692,  0.14077318,  1.76760095],
#         [-0.78777374, -0.06172207,  0.23842679,  0.07477245]]])

# %%
np.random.randint(3)
# Out:
# 2

# %%
np.random.randint(2, size=5)
# Out:
# array([1, 0, 1, 1, 0])

# %%
np.random.randint(1, 5)
# Out:
# 3

# %%
np.random.randint(1, 5, size=(2,2))
# Out:
# array([[3, 2],
#        [2, 4]])

# %%
np.random.sample(size=(2,2))
# Out:
# array([[0.2812169 , 0.86508964],
#        [0.07312331, 0.66033189]])

# %%
np.random.choice(5,3,replace=False)
# Out:
# array([1, 3, 0])

# %%
np.random.choice(5, size=(2,2))
# Out:
# array([[4, 1],
#        [2, 1]])

# %%
np.random.choice(5,(2,2))
# Out:
# array([[2, 4],
#        [1, 3]])

# %%
c = [1,0,1,1,1,1,0]

# %%
np.random.choice(c,(2,2))
# Out:
# array([[1, 0],
#        [1, 1]])

# %%
np.arange(5)
# Out:
# array([0, 1, 2, 3, 4])

# %%
np.random.choice(5, 3, replace=False)
# Out:
# array([4, 0, 3])

# %%
demo_list = ['lenovo', 'sansumg','moto','xiaomi', 'iphone']
np.random.choice(demo_list,size=(2,2))
# Out:
# array([['xiaomi', 'moto'],
#        ['iphone', 'moto']], dtype='<U7')

# %%
demo_list = ['lenovo', 'sansumg','moto','xiaomi', 'iphone']
np.random.choice(demo_list,size=(2,2), p=[0.1,0.6,0.1,0.1,0.1])
# Out:
# array([['moto', 'sansumg'],
#        ['sansumg', 'sansumg']], dtype='<U7')

# %%
np.random.seed(0)
np.random.rand(5)
# Out:
# array([0.5488135 , 0.71518937, 0.60276338, 0.54488318, 0.4236548 ])

# %%
np.random.rand(5)
# Out:
# array([0.79172504, 0.52889492, 0.56804456, 0.92559664, 0.07103606])

# %%
np.random.seed(1)
np.random.rand(5)
# Out:
# array([4.17022005e-01, 7.20324493e-01, 1.14374817e-04, 3.02332573e-01,
#        1.46755891e-01])

# %% [markdown]
# ---

# %% [markdown]
# ## Markdown

# %% [markdown]
# $f(x) = x^2-4x+1$

# %% [markdown]
# $$\int_a^b f(x) \, dx$$

# %%
#數學函式
from sympy import *

x = symbols('x')
init_printing()
(sin(x)*(1+x)**2)/(2*x**2+3)
# Out:
#        2
# (x + 1) ⋅sin(x)
# ───────────────
#        2
#     2⋅x  + 3

# %% [markdown]
# ## List

# %%
L = [3, 87, -5, 9]
G = [1, 2, 8, 10]

# %%
#list使用'+'運算符，為將兩個list串接，而非相加
L+G
# Out:
# [3, 87, -5, 9, 1, 2, 8, 10]

# %%
#L重複2次
L*2
# Out:
# [3, 87, -5, 9, 3, 87, -5, 9]

# %% [markdown]
# ## String

# %%
message = '''sample
try
this
method!
'''

# %%
print(message)
# Out:
# sample
# try
# this
# method!

# %%
message #\n：換行
# Out:
# 'sample\ntry\nthis\nmethod!\n'

# %% [markdown]
# ## Interactive

# %%
a = input("a = ") #可提示要輸入的東西
# Out:
# a = 67

# %%
a #字串
# Out:
# '67'

# %%
m = input('美金價格')
# Out:
# 美金價格120

# %%
m
# Out:
# '120'

# %%
m * 30.5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-178-ba9235c1c069> in <module>
# ----> 1 m * 30.5
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
float(m) * 30.5 #將字串轉換為符點數
# Out:
# 3660.0

# %%
m = input('美金價格')
twd = float(m) * 30.5
print('合台幣', twd, '元')
# Out:
# 美金價格120
# 合台幣 3660.0 元

# %%
message = input('>> ')
print('拍拍')
# Out:
# >> nothing
# 拍拍
